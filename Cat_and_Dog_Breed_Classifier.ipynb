# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthakpruthi/deep-learning-fastai/blob/master/Cat_and_Dog_Breed_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cat and Dog Classifier - Lesson 1 - Fastai

# %% [markdown]
# Below Cell contains code which is not in python. These are magic functions. First two lines ensure that if there is something change in library, code will reload it and next line forces to plot matplotlib in this notebook

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
import torch
torch.cuda.device(0)

# %%
#torch.set_default_tensor_type('cuda')
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %% [markdown]
# Normally we don't use * for importing, because it imports functions as it is, and then there can be clashes with our function names

# %%
# batch-size
bs = 64

# %% [markdown]
# ## Looking at the Data

# %% [markdown]
# We will use Oxford-IIIT Pet Dataset which features 12 cat and 25 dog breeds, and each category rough have 200 images.

# %% [markdown]
# fastai.datasets contains Oxford-IIIT Pet data set so we can import dataset using **untar_data()** function

# %%
path = untar_data(URLs.PETS);

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations')]

# %%
type(path)
# Out:
# pathlib.PosixPath

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/american_bulldog_164.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/japanese_chin_61.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_65.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Persian_150.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Sphynx_231.jpg')]

# %%
len(fnames)
# Out:
# 7390

# %%
np.random.seed(0)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs
                                  ).normalize(imagenet_stats)

# %%
imagenet_stats
# Out:
# ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %% [markdown]
# ## Training resnet 34

# %% [markdown]
# Now we will start training our model. We will use a convolutional neural network backbone and a fully connected head with a single hidden layer as a classifier.

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.383897</td>
#       <td>0.305955</td>
#       <td>0.099459</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.598174</td>
#       <td>0.316772</td>
#       <td>0.096076</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.378240</td>
#       <td>0.229715</td>
#       <td>0.075101</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.269610</td>
#       <td>0.213559</td>
#       <td>0.070365</td>
#       <td>01:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage01', return_path = True)
# Out:
# PosixPath('/root/.fastai/data/oxford-iiit-pet/images/models/stage01.pth')

# %% [markdown]
# # **Result**
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
# Out:
# <h4 id="_cl_int_plot_top_losses" class="doc_header"><code>_cl_int_plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L166" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>_cl_int_plot_top_losses</code>(<strong><code>k</code></strong>, <strong><code>largest</code></strong>=<strong><em><code>True</code></em></strong>, <strong><code>figsize</code></strong>=<strong><em><code>(12, 12)</code></em></strong>, <strong><code>heatmap</code></strong>:<code>bool</code>=<strong><em><code>False</code></em></strong>, <strong><code>heatmap_thresh</code></strong>:<code>int</code>=<strong><em><code>16</code></em></strong>, <strong><code>alpha</code></strong>:<code>float</code>=<strong><em><code>0.6</code></em></strong>, <strong><code>cmap</code></strong>:<code>str</code>=<strong><em><
# ...

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Ragdoll', 'Birman', 9),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 7),
#  ('Russian_Blue', 'British_Shorthair', 5),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 5),
#  ('Bengal', 'Egyptian_Mau', 4),
#  ('basset_hound', 'beagle', 4),
#  ('boxer', 'american_bulldog', 4),
#  ('yorkshire_terrier', 'havanese', 3),
#  ('Bengal', 'Maine_Coon', 2),
#  ('Birman', 'Ragdoll', 2),
#  ('British_Shorthair', 'Russian_Blue', 2),
#  ('Maine_Coon', 'Bengal', 2),
#  ('Maine_Coon', 'Ragdoll', 2),
#  ('Persian', 'Ragdoll', 2),
#  ('Siamese', 'Birman', 2),
#  ('american_bulldog', 'american_pit_bull_terrier', 2),
#  ('beagle', 'american_bulldog', 2),
#  ('boxer', 'staffordshire_bull_terrier', 2),
#  ('chihuahua', 'shiba_inu', 2),
#  ('english_cocker_spaniel', 'english_setter', 2),
#  ('staffordshire_bull_terrier', 'american_bulldog', 2)]

# %% [markdown]
# # **Unfreezing, Fine-Tuning and Learning Rates**

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.676208</td>
#       <td>0.354641</td>
#       <td>0.115020</td>
#       <td>01:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage01');

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.245618</td>
#       <td>0.205351</td>
#       <td>0.066982</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.221976</td>
#       <td>0.199390</td>
#       <td>0.062923</td>
#       <td>01:33</td>
#     </tr>
#   </tbody>
# </table>
